# %%
import pandas as pd
import json
import os

# %%
filepath = ("./Resources/english-premier-league-match-data/datafile 2/season17-18/season_stats.json")
# filepath = os.path.join(".", "Resources", "english-premier-league-match-data", "datafile 2", "season17-18")

# %%
with open(filepath) as jsonfile:
    match_stats_json = json.load(jsonfile)

# %%
# for key, value in match_stats_json.items():
#     for key2,value2 in value.items():
#         for key3, value3 in value2['Player_stats'].items():
#             print(key3)

# %%
player_details = []

for match, team in match_stats_json.items():
    for team2,agg_stats in team.items():
        for x,y in agg_stats['team_details'].items():
            if x == 'team_name':
                team_name = y
#                 save_stats.append(team_name)
        for player_name, player_stats in agg_stats['Player_stats'].items():
            save_stats=[]
            save_stats.append(player_name)
            save_stats.append(team_name)
            for key,value in player_stats['player_details'].items():
                if key == 'player_position_info':
                    save_stats.append(value)
                if key == 'player_rating':
                    save_stats.append(value)
#             print(save_stats[2])
            player_details.append(save_stats)

# %%
columns = ['name','team','position','match rating']
df=pd.DataFrame(player_details, columns = columns)

# %%
df
# Out:
#                            name             team position match rating
# 0                   Jonas Lössl     Huddersfield       GK         6.61
# 1               Terence Kongolo     Huddersfield       DC         6.19
# 2                    Chris Löwe     Huddersfield       DL         5.96
# 3                         Zanka     Huddersfield       DC         6.65
# 4         Christopher Schindler     Huddersfield       DC         6.58
# 5           Florent Hadergjonaj     Huddersfield       DR         6.33
# 6                Philip Billing     Huddersfield       MC         5.61
# 7                    Aaron Mooy     Huddersfield       MC         5.95
# 8                 Jonathan Hogg     Huddersfield       MC         5.92
# 9              Laurent Depoitre     Huddersfield       FW         6.18
# 10                 Steve Mounie     Huddersfield       FW         5.84
# 11                  Tommy Smith     Huddersfield      Sub            0
# 12                Collin Quaner     Huddersfield      Sub         5.99
# 13           Rajiv van La Parra     Huddersfield      Sub         6.03
# 14               Michael Hefele     Huddersfield      Sub            0
# 15                 Joel Coleman     Huddersfield      Sub            0
# 16               Alex Pritchard     Huddersfield      Sub            0
# 17                     Tom Ince     Huddersfield      Sub         6.12
# 18                 Loris Karius        Liverpool       GK          7.1
# 19                 Joseph Gomez        Liverpool       DR         7.22
# 20                   Joel Matip        Liverpool       DC          7.7
# 21             Andrew Robertson        Liverpool       DL         6.56
# 22                 Dejan Lovren        Liverpool       DC         8.04
# 23             Jordan Henderson        Liverpool       MC         7.04
# 24                     Emre Can        Liverpool       MC         9.05
# 25                 James Milner        Liverpool       MC         7.56
# 26                Mohamed Salah        Liverpool      FWR         7.38
# 27                   Sadio Mané        Liverpool      FWL         7.26
# 28              Roberto Firmino        Liverpool       FW          8.1
# 29                   Danny Ings        Liverpool      Sub            0
# ...                         ...              ...      ...          ...
# 13645              Badou Ndiaye            Stoke       MC         6.57
# 13646                 Joe Allen            Stoke       MC         6.25
# 13647           Xherdan Shaqiri            Stoke      FWR         6.67
# 13648  Eric Maxim Choupo-Moting            Stoke      FWL         6.33
# 13649                      Jesé            Stoke       FW         5.86
# 13650              Glen Johnson            Stoke      Sub            0
# 13651            Ryan Shawcross            Stoke      Sub            0
# 13652             Ramadan Sobhi            Stoke      Sub         6.17
# 13653              Charlie Adam            Stoke      Sub            0
# 13654           Darren Fletcher            Stoke      Sub            0
# 13655            Jakob Haugaard            Stoke      Sub            0
# 13656              Peter Crouch            Stoke      Sub         6.26
# 13657                   Ederson  Manchester City       GK         6.62
# 13658           Vincent Kompany  Manchester City       DC         7.58
# 13659          Nicolás Otamendi  Manchester City       DC         7.41
# 13660               Kyle Walker  Manchester City       DR         7.45
# 13661       Oleksandr Zinchenko  Manchester City       DL         6.92
# 13662               David Silva  Manchester City       MC          9.1
# 13663           Kevin De Bruyne  Manchester City       MC         7.64
# 13664               Fernandinho  Manchester City       MC         7.13
# 13665                Leroy Sané  Manchester City      FWL         7.16
# 13666             Gabriel Jesus  Manchester City       FW         7.08
# 13667           Raheem Sterling  Manchester City      FWR         7.64
# 13668           Aymeric Laporte  Manchester City      Sub            0
# 13669            Bernardo Silva  Manchester City      Sub         6.18
# 13670                Yaya Touré  Manchester City      Sub            0
# 13671             Claudio Bravo  Manchester City      Sub            0
# 13672               John Stones  Manchester City      Sub            0
# 13673                    Danilo  Manchester City      Sub            0
# 13674            Ilkay Gündogan  Manchester City      Sub         6.18
#
# [13675 rows x 4 columns]

# %%
# original try to get the player_details dictionary info

player_details = {}
for match, team in match_stats_json.items():
    for team2,agg_stats in team.items():
        for player_name, player_stats in agg_stats['Player_stats'].items():
            save_stats = []
            for key,value in player_stats['player_details'].items():
                save_stats.append(value)
                player_details.update({player_name:save_stats})

# %%
match_stats = []
for match, team in match_stats_json.items():
    for team2,agg_stats in team.items():
        for player_name, player_stats in agg_stats['Player_stats'].items():
            save_stats2 = []
            save_stats2.append(player_name)
            for key,value in player_stats['Match_stats'].items():
                if key == 'touches':
                    save_stats2.append(value)
#                 match_stats.update({player_name:save_stats2})
            match_stats.append(save_stats2)

# %%
match_stats[0:20]
# Out:
# [['Jonas Lössl', '39'],
#  ['Terence Kongolo', '30'],
#  ['Chris Löwe', '38'],
#  ['Zanka', '44'],
#  ['Christopher Schindler', '46'],
#  ['Florent Hadergjonaj', '54'],
#  ['Philip Billing', '44'],
#  ['Aaron Mooy', '47'],
#  ['Jonathan Hogg', '53'],
#  ['Laurent Depoitre', '40'],
#  ['Steve Mounie', '16'],
#  ['Tommy Smith'],
#  ['Collin Quaner', '13'],
#  ['Rajiv van La Parra', '9'],
#  ['Michael Hefele'],
#  ['Joel Coleman'],
#  ['Alex Pritchard'],
#  ['Tom Ince', '12'],
#  ['Loris Karius', '41'],
#  ['Joseph Gomez', '119']]

# %%
pd.DataFrame.from_dict(match_stats, orient='index')
# Out:
#                         0     1     2     3     4     5     6     7     8   \
# Jonas Lössl             40     5    29     1     1    15  None  None  None
# Terence Kongolo         44     7     1    15     1     3    11  None  None
# Chris Löwe              36     1     1    23     1     3    16  None  None
